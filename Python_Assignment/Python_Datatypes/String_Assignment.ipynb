# %%
name = "python"

# %%
type(name)
# Out:
# str

# %%
# Upper case

name.upper()
# Out:
# 'PYTHON'

# %%
# Lower Case

name.lower()
# Out:
# 'python'

# %%
# Reverse a string
a = ""
for i in range(len(name)-1,-1,-1):
    a += name[i]
print(a)
# Out:
# nohtyp

# %%
name = "Python123"
a = ""
for i in name:
    if i.isalpha():
        a+=i
print(a)
# Out:
# Python
