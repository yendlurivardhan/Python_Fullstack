# %%
# Write a program to check whether a person is eligible to vote (age ≥ 18).

Age = int(input("Enter your age: "))
print(f"Your age is {Age}")
if Age >= 18:
    print("Eligible to vote")
else:
    print("Not Eligible to vote")
# Out:
# Your age is 18
# Eligible to vote

# %%
# Write a program to check whether a number is divisible by 5.

Number = int(input("Enter number: "))
if Number % 5 == 0:
    print(f"{Number} is divisible by 5")
else:
    print(f"{Number} is not divisible by 5")
# Out:
# 6 is not divisible by 5

# %%
# Write a program to check whether a number is multiple of 3 and 7.

Number = int(input("Enter number: "))
if Number % 3 == 0 and Number % 7 == 0:
    print(f"{Number} is dividible by both 3 and 7")
else:
    print(f"{Number} is not divisible by 3 and 7")
# Out:
# 4 is not divisible by 3 and 7

# %%
# Write a program to find the largest of three numbers.

Num1 = int(input("Enter number: "))
Num2 = int(input("Enter number: "))
Num3 = int(input("Enter number: "))
if Num1>Num2 and Num1>Num3:
    print(f"{Num1} is largest number")
elif Num2>Num1 and Num2>Num3:
    print(f"{Num2} is largest number")
else:
    print(f"{Num3} is largest number")
# Out:
# 3 is largest number

# %%
# Write a program to check whether a number is a leap year.

year = int(input("Enter year: "))
if year%4==0 and (year % 100 != 0 or year % 400 == 0):
    print(f"{year} is Leap year")
else:
    print(f"{year} is Not Leap year")
# Out:
# 2022 is Not Leap year

# %%
# Write a program to check whether a student passed or failed
# Pass if marks ≥ 35.

Marks = int(input("Enter marks: "))
if Marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
